# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib
import os

# %%
seg_01 = nib.load("./seg_images/seg-01.nii.gz").get_fdata()
seg_04 = nib.load("./seg_images/seg-04.nii.gz").get_fdata()
seg_05 = nib.load("./seg_images/seg-05.nii.gz").get_fdata()
seg_07 = nib.load("./seg_images/seg-07.nii.gz").get_fdata()
seg_14 = nib.load("./seg_images/seg-14.nii.gz").get_fdata()
seg_070 = nib.load("./seg_images/seg-070.nii.gz").get_fdata()
seg_148 = nib.load("./seg_images/seg-148.nii.gz").get_fdata()

fig, axs = plt.subplots(3, 3)

# axs[0, 0].plot(x1, y1)



# Plot the registered image using plt.imshow()
axs[0,0].set_title("Paciente 1", fontsize=8)
axs[0,0].set_xlim([0, seg_01.shape[0]])
axs[0,0].set_ylim([0, seg_01.shape[1]])
axs[0,0].imshow(seg_01[:,:,23], cmap="gray")


axs[0,1].set_title("Paciente 4", fontsize=8)
axs[0,1].set_xlim([0, seg_04.shape[0]])
axs[0,1].set_ylim([0, seg_04.shape[1]])
axs[0,1].imshow(seg_04[:,:,23], cmap="gray")

axs[0,2].set_title("Paciente 5", fontsize=8)
axs[0,2].set_xlim([0, seg_05.shape[0]])
axs[0,2].set_ylim([0, seg_05.shape[1]])
axs[0,2].imshow(seg_05[:,:,23], cmap="gray")

axs[1,0].set_title("Paciente 7", fontsize=8)
axs[1,0].set_xlim([0, seg_07.shape[0]])
axs[1,0].set_ylim([0, seg_07.shape[1]])
axs[1,0].imshow(seg_07[:,:,23], cmap="gray")

axs[1,1].set_title("Paciente 14", fontsize=8)
axs[1,1].set_xlim([0, seg_14.shape[0]])
axs[1,1].set_ylim([0, seg_14.shape[1]])
axs[1,1].imshow(seg_14[:,:,23], cmap="gray")

axs[1,2].set_title("Paciente 070", fontsize=8)
axs[1,2].set_xlim([0, seg_070.shape[0]])
axs[1,2].set_ylim([0, seg_070.shape[1]])
axs[1,2].imshow(seg_070[:,:,23], cmap="gray")

axs[2,1].set_title("Paciente 148", fontsize=8)
axs[2,1].set_xlim([0, seg_148.shape[0]])
axs[2,1].set_ylim([0, seg_148.shape[1]])
axs[2,1].imshow(seg_148[:,:,23], cmap="gray")

axs[0,0].axis('off')
axs[0,1].axis('off')
axs[0,2].axis('off')
axs[1,0].axis('off')
axs[1,1].axis('off')
axs[1,2].axis('off')
axs[2,0].axis('off')
axs[2,1].axis('off')
axs[2,2].axis('off')
# Invert the y-axis
# Añade el texto de la leyenda

plt.tight_layout()
# plt.show()

# %%
seg_01 = nib.load("./seg_images/seg-01.nii.gz").get_fdata()

# Plot image
plt.imshow(seg_01[:,:,25], cmap="gray")
plt.axis('off')
plt.show()

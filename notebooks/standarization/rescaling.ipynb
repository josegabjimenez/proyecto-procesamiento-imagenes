# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# %%
image_data = nib.load('../../images/1/IR.nii.gz').get_fdata()

# %%
plt.hist(image_data[image_data>10].flatten(), 100)
# Out:
# (array([1.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         1.000000e+00, 1.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 1.000000e+00, 4.000000e+00,
#         2.000000e+00, 2.000000e+00, 1.000000e+00, 2.000000e+00,
#         2.000000e+00, 3.000000e+00, 3.000000e+00, 2.000000e+00,
#         5.000000e+00, 6.000000e+00, 5.000000e+00, 4.000000e+00,
#         7.000000e+00, 6.000000e+00, 7.000000e+00, 1.000000e+00,
#         5.000000e+00, 1.400000e+01, 1.100000e+01, 1.300000e+01,
#         1.900000e+01, 2.400000e+01, 5.900000e+01, 1.120000e+02,
#         2.430000e+02, 7.700000e+02, 2.355000e+03, 3.623000e+03,
#         3.609000e+03, 3.154000e+03, 2.824000e+03, 3.149000e+03,
#         3.838000e+03, 4.276000e+03, 5.044000e+03, 5.900000e+03,
#         6.470000e+03, 7.396000e+03, 7.993000e+03, 8.563000e+03,
#         9.154000e+03, 9.675000e+03, 1.012200e+04, 1.094500e+04,
# ...

# %%
plt.imshow(image_data[:, :, 20], cmap='gray')

# %%
min_value = image_data.min()
max_value = image_data.max()

image_data_rescaled = (image_data - min_value) / (max_value - min_value)

# %%
plt.hist(image_data_rescaled[image_data_rescaled>0.01].flatten(), 100)
# Out:
# (array([2.44183e+05, 1.50280e+05, 1.19990e+05, 1.07551e+05, 9.79980e+04,
#         9.35660e+04, 9.22400e+04, 9.27090e+04, 9.55780e+04, 1.01091e+05,
#         1.09411e+05, 1.20720e+05, 1.36504e+05, 1.59080e+05, 1.86949e+05,
#         2.09691e+05, 2.18757e+05, 2.07576e+05, 1.85390e+05, 1.58767e+05,
#         1.36009e+05, 1.18492e+05, 1.04755e+05, 9.64400e+04, 9.33630e+04,
#         1.00972e+05, 1.22580e+05, 1.28380e+05, 9.20400e+04, 5.45290e+04,
#         3.47680e+04, 2.58000e+04, 2.10060e+04, 1.80990e+04, 1.52490e+04,
#         1.26580e+04, 1.05470e+04, 8.80800e+03, 7.40400e+03, 6.09500e+03,
#         5.06200e+03, 4.12700e+03, 3.50300e+03, 2.89100e+03, 2.43900e+03,
#         1.89300e+03, 1.72500e+03, 1.39700e+03, 1.13500e+03, 1.01800e+03,
#         8.19000e+02, 7.23000e+02, 5.90000e+02, 5.28000e+02, 4.78000e+02,
#         4.55000e+02, 3.56000e+02, 3.48000e+02, 2.96000e+02, 2.69000e+02,
#         2.55000e+02, 2.34000e+02, 2.65000e+02, 2.53000e+02, 2.16000e+02,
# ...

# %%
plt.imshow(image_data_rescaled[:, :, 100])
